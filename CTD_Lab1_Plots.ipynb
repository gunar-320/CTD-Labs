# %% [markdown]
# <a href="https://colab.research.google.com/github/gunar-320/CTD-Labs/blob/main/CTD_Lab1_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#For Ideal Part B
import matplotlib.pyplot as plt
import numpy as np
x_coordinates = (50,100,500,750,1000,2500,5000,10000)
y_coordinates = (99.52,99.76,99.93,99.95,99.95,99.968,99.9658166,99.979)
plt.xlabel("Load Resistance")
plt.ylabel("Efficiency of Power Source")
plt.plot(x_coordinates,y_coordinates)

# %%
# For Non Ideal Part -B
import matplotlib.pyplot as plt
import numpy as np
x_coordinates = [1,5,10,50,100,500,750,1000,2500,5000,10000]
y_coordinates = [14.61,43.94,57.45,62.70,51.77,19.86,14.51,11.13,4.84,2.48,1.25]
plt.xlabel("Load Resistance")
plt.ylabel("Efficiency of Power Source")
plt.plot(x_coordinates,y_coordinates)

# %%
import matplotlib.pyplot as plt
import numpy as np
x_coordinates = [1,5,10,50,100,500,750,1000,2500,5000,10000]
y_coordinates = [15.1,44.9,58.35,63.05,51.92,19.91,14.50,11.16,4.84,2.5,1.25]
plt.xlabel("Load Resistance")
plt.ylabel("Efficiency of Transformers")
plt.plot(x_coordinates,y_coordinates)
