# %% [markdown]
# <a href="https://colab.research.google.com/github/gunar-320/CTD-Labs/blob/main/CTD_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#For Ideal Part B
import matplotlib.pyplot as plt
import numpy as np
x_coordinates = (50,100,500,750,1000,2500,5000,10000)
y_coordinates = (99.5266,99.763859,99.93681,99.95036,99.9535097,99.968022,99.9658166,99.979097)
plt.xlabel("Load Resistance")
plt.ylabel("Efficiency of Power Source")
plt.plot(x_coordinates,y_coordinates)

# %%
# For Non Ideal Part -B
import matplotlib.pyplot as plt
import numpy as np
x_coordinates = [1,5,10,50,100,500,750,1000,2500,5000,10000]
y_coordinates = [14.613,43.94,57.45567,62.7018,51.77,19.86,14.5143,11.1333,4.8416,2.48,1.256]
plt.xlabel("Load Resistance")
plt.ylabel("Efficiency of Power Source")
plt.plot(x_coordinates,y_coordinates)

# %%
import matplotlib.pyplot as plt
import numpy as np
x_coordinates = [1,5,10,50,100,500,750,1000,2500,5000,10000]
y_coordinates = [15.132,44.93,58.3591,63.051,51.92,19.91,14.5083,11.16,4.84932,2.5,1.258]
plt.xlabel("Load Resistance")
plt.ylabel("Efficiency of Transformers")
plt.plot(x_coordinates,y_coordinates)
